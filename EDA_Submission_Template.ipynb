# %% [markdown]
# <a href="https://colab.research.google.com/github/gorakhgupta00/EDA-Project../blob/main/EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - INDIVIDUAL
# ##### **NAME -**Gorakh Gupta

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# *   In this project we begin to explore the dataset in which in which Hotel Comprises of two types of hotels i.e. City Hotel and Resort Hotel.
# *   In this dataset there are total 119390 rows and 32 columns.<br>
# *   This Dataset does have duplicete as well as null values.There are total of 31994 duplicte values and four columns have missing values.
# *   The Maximum number of missing values are from 'Company' column then followed by 'Agent', 'Contry','Children' columns
# *   In this dataset have both missing and duplicate values, so we deal with missing and null values by replacing it and drop the duplicates.
# *   In this project before performing EDA on dataset we perform data cleaning and data manipulation operation.
# *   Furthure  we used various basic functions and attributes i.e. info(),describe(),sum(),count(),Duplicated()
# *   Furthure we converted data types into appropriate datatype.
# *   Before visualizing any type of data from dataset we need to do data wrangling .So we check the null values of all the columns.
# *   Then we have started the data visualization part we have done the visualization in a structured way while following 'UBM' rule:
# *   U- Univariate Analysis (for single columns for categorical columns)
# *   B- Bivariate Analysis ( Numerical -Categorical,Numerical-Numerical,Categorical-Categorical)
# *   M- Multivariate Analysis(for Multple columns)
# *   In data visulization process we have used various charts and graphs to extract the proper insights that gives the bussinesss outcomes.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/gorakhgupta00/EDA-Project/blob/main/Copy_of_Copy_of_Sample_EDA_Submission_Template.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyse the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Explore and Analyze the data to discover important factors that improve  the hotel bookings.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
file="/content/gdrive/MyDrive/Module_2/week/EDA_Project/Hotel Bookings (1).csv"
df = pd.read_csv(file)
df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 16451   Resort Hotel            0         37               2015
# 44337     City Hotel            0         61               2015
# 118075    City Hotel            0        295               2017
# 80036     City Hotel            0          2               2016
# 84461     City Hotel            0          2               2016
# 108026    City Hotel            0        151               2017
# 16857   Resort Hotel            0        254               2015
# 36779   Resort Hotel            0          2               2017
# 18179   Resort Hotel            0         32               2015
# 79468     City Hotel            1          1               2015
#
#        arrival_date_month  arrival_date_week_number  \
# 16451              August                        35
# 44337             October                        41
# 118075             August                        32
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
total_duplicate_rows=df.duplicated().sum()
total_duplicate_rows
# Out:
# 31994

# %%
# print duplicate rows
duplicate_rows=df[df.duplicated(keep=False)]
duplicate_rows
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 21      Resort Hotel            0         72               2015
# 22      Resort Hotel            0         72               2015
# 39      Resort Hotel            0         70               2015
# ...              ...          ...        ...                ...
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119372    City Hotel            0        175               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 4                    July                        27
# 5                    July                        27
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_val=df.isna().sum().sort_values(ascending=False)

# %%
# Visualizing the missing values
#set plot size
plt.figure(figsize=(10,8))
# set labels
plt.title('Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')

#plot the graph
missing_val.plot(kind='bar')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   This dataset contains 119390 rows and 32 columns.
# *   All the columns are divided into three data types: int64,float64,object.
# *   This dataset have duplicates as well as null values. There are total 31994 duplicate values and four columns have null values.
# *   The maximum number of  missing values from 'Company' column and then followed by 'agent','country' and 'chidren' columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * hotel: Name of the hotel (Resort Hotel or City Hotel)
#
# * is canceled: If the booking was cancelled (1) or not (0)
#
# * lead time: Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# * arrival_date_year: Year of arrival date
#
# * arrival_date_month: Month of month arrival date
#
# * arrival_date_week_number: Week number for arrival date
#
# * arrival_date_day_of_month: Day of arrival date
#
# * stays_in_weekend_nights: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# * stays_in_week_nights: Number of weeknights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# * adults: Number of adults among guests
# * children: Number of children among guests
# * babies: Number of babies among guests
# * meal: kind of meal opted for
# * market segment: which segment customer belongs to
#
# * distribution channel: Name of booking distribution channel. The term "TA" means "Travel Agents" and "TO" means "Tour Operators"
#
# * is_repeated_guest: If the booking was done from a repeated guest (1) or not (0)
#
# * previous_cancellations: Number of previous bookings that were cancelled by the customer prior to the current booking
#
# * previous bookings_not_canceled: Number of previous bookings not cancelled by the customer prior to the current booking
#
# * reserved_room_type: Code of room type reserved
#
# * assigned_room_type: Code of room type assigned
#
# * booking changes: Number of changes/amendments made to the booking
#
# * deposit_type: Type of the deposit made by the guest
#
# * agent: ID of travel agent who made the booking
#
# * company: ID of the company that made the booking
#
# * days_in_waiting list: Number of days the booking was in the waiting list
#
# * customer_type: Type of customer, assuming one of four categories
#
# * adr: Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# * required_car_parking spaces: Number of car parking spaces required by the customer
#
# * total_of_special_requests: Number of special requests made by the customer
#
# * reservation_status: Reservation status (Cancelled, Check-Out or No-Show)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns.tolist():
  print(f"Number of unique values in {column} is: {df[column].nunique()}")
# Out:
# Number of unique values in hotel is: 2
# Number of unique values in is_canceled is: 2
# Number of unique values in lead_time is: 479
# Number of unique values in arrival_date_year is: 3
# Number of unique values in arrival_date_month is: 12
# Number of unique values in arrival_date_week_number is: 53
# Number of unique values in arrival_date_day_of_month is: 31
# Number of unique values in stays_in_weekend_nights is: 17
# Number of unique values in stays_in_week_nights is: 35
# Number of unique values in adults is: 14
# Number of unique values in children is: 5
# Number of unique values in babies is: 5
# Number of unique values in meal is: 5
# Number of unique values in country is: 177
# Number of unique values in market_segment is: 8
# Number of unique values in distribution_channel is: 5
# Number of unique values in is_repeated_guest is: 2
# Number of unique values in previous_cancellations is: 15
# Number of unique values in previous_bookings_not_canceled is: 73
# ...

# %%
for col in df[['hotel','arrival_date_year','is_canceled','customer_type','reserved_room_type','deposit_type','meal']]:
    print(f"{col}: \n{df[col].unique()}\n")
# Out:
# hotel:
# ['Resort Hotel' 'City Hotel']
#
# arrival_date_year:
# [2015 2016 2017]
#
# is_canceled:
# [0 1]
#
# customer_type:
# ['Transient' 'Contract' 'Transient-Party' 'Group']
#
# reserved_room_type:
# ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
#
# deposit_type:
# ['No Deposit' 'Refundable' 'Non Refund']
#
# meal:
# ['BB' 'FB' 'HB' 'SC' 'Undefined']

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# first dealing with null values
# checking for null
df.isna().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# filling null with some values so null values doesn't affect our result
df[['company','agent','children']]=df[['company','agent','children']].fillna(0)
df['country']=df['country'].fillna('other')

# %%
#recheck for null values
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# 2nd we check for duplicate values in dataset and handle them

total_dupl_rows=df.duplicated().sum()
total_dupl_rows
# Out:
# 31994

# %%
# print duplicate rows
duplicate_rows=df[df.duplicated(keep=False)]
duplicate_rows
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 21      Resort Hotel            0         72               2015
# 22      Resort Hotel            0         72               2015
# 39      Resort Hotel            0         70               2015
# ...              ...          ...        ...                ...
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119372    City Hotel            0        175               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 4                    July                        27
# 5                    July                        27
# ...

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (87396, 32)

# %%
# adults, babies and children cant be zero at same time, so dropping the rows having all these zero at same time because that simply means no booking were made

filter = (df.children == 0) & (df.adults == 0) & (df.babies == 0)
df[filter]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2224    Resort Hotel            0          1               2015
# 2409    Resort Hotel            0          0               2015
# 3181    Resort Hotel            0         36               2015
# 3684    Resort Hotel            0        165               2015
# 3708    Resort Hotel            0        165               2015
# ...              ...          ...        ...                ...
# 115029    City Hotel            0        107               2017
# 115091    City Hotel            0          1               2017
# 116251    City Hotel            0         44               2017
# 116534    City Hotel            0          2               2017
# 117087    City Hotel            0        170               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2224              October                        41
# 2409              October                        42
# ...

# %%
df.shape
# Out:
# (87396, 32)

# %%
df.drop(df[filter].index,inplace=True)

# %%
df.shape
# Out:
# (87230, 32)

# %% [markdown]
# **Converting Columns to appropriate Datatype.**

# %%
# changing datatype of column 'reservation_status_date' from object to datetype.
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

# %%
df['reservation_status_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# **Adding Important Columns:**

# %%
# Adding total number of people as column
df['total_people']=df['adults']+df['children']+df['babies']
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  company  \
# 0                        0                     0       2  ...    0.0      0.0
# ...

# %%
# Adding total staying days in hotels
df['total_stay']=df['stays_in_weekend_nights']+df['stays_in_week_nights']
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...      0.0
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We have done the following manupulations and the insights found by us are as follows:-
#
# *  We found that there were four columns containing null values So we Had Null values in columns- Company, agent, Country and children.
#
# 1. So,for company and agent We have filled the missing values with 0
#
# 2. for country. We have fill Missing values with oject Others' (assuming while collecting data country was not found so user selected the 'Others' option.)
#
# 3. As the count of missing values in Children Column was only 4, so it was replaced with 0 considering no childrens.
#
# *  This dataset was also containing duplicate values so duplicate values was dropped.
#
# *  We found that there were some rows in which the combining values of adults,babies and childrens was O so this simply means there were no guests as 0 indicates presence of none. So,there were no bookings made. So,as a result, We dropped the rows where combining values of adults,babies and children columns was 0.
#
# *  The data type of 'reservation_status_date' column was object type so it was changed to date type format for better use.
#
# *  There were two new columns that was added, one is 'total people' and other is 'total_stay'

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1-**For Most Preffered Hotel(Univariate)**

# %%
# Chart - 1 visualization code
# Visualizing by pie-chart
df['hotel'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(6,6),fontsize=18)
plt.title('Pie-Chart For Most Preffered Hotel',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Pie-Chart For Most Preffered Hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie-chart expresses ap part to whole relationship in your data. It's easy to explain the percentage comparision through area covered in a circle with different colours.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart,We got to know that City Hotel is most preffered hotel by guests. Thus city hotels has maximum bookings.66.4% guests preffered city hotel while only 33.6 % guests have shown interest in resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, for both types of Hotels, this graph have some positive business impacts.
#
# City Hotel are doing well so they are Providing more services to attract more quest to increase more revenue So they are doing well But in case

# %% [markdown]
# #### Chart - 2-  **Hotel Type with highest adr(Bivariate with Categorical-Numerical)**

# %%
# Chart - 2 visualization code
# grouping  the hotel
grp_by_hotel=df.groupby('hotel')

# %%
#grouping by hotel adr
highest_adr=grp_by_hotel['adr'].mean().reset_index()

# %%
#set plot size
plt.figure(figsize=(10,8))
# set labels
plt.xlabel('Hotel-Type',fontsize=15)
plt.ylabel('ADR',fontsize=15)
plt.title('Average ADR of each Hotel-Type')

#plot the graph
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'Average ADR of each Hotel-Type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other
#
# statistics, such as percentages.
#
# To show the average adr of each hotel type in a clear and feasible way. We have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has the highest ADR. This means city hotels are generating more revenues than the resort hotels. More the ADR more will be the revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# So, City hotel can do more advertising to get more customers that will ultimately add up to their revenue. Thus, the city hotels are already enjoying high adr but a bit more of positive efforts towards growth will definitely adds alot to their growth and overall revenue.

# %% [markdown]
# #### Chart - 3- **Percentage of repeated Guests**

# %%
# Chart - 3 visualization code
#Visualizing by pie_chart

df['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),autopct='%1.1f%%',shadow=True,figsize=(6,6),fontsize=18)
plt.title('Percentage of repeated Guests',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percentage of repeated Guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are used to represent the proportional data or relative data in a single chart. The concept of pie slices is used to show the percentage of a particular data from the whole pie. Thus, We have used to show the percentage of repeated guests or not (where 0 is not repeated guest and 1 is repeated guest) through pie chart with different colored area under a circle.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Repeated guests are very few which only 3.9% while 96,1 % guests are not returning to the same hotel. So,it's a matter of deep thinking and taking proper steps to increase the repeated guests numbers. In order to retained the guests management should take feedbacks from guests and try to imporve the services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the proportion of repeated guests is very much low,so if hotels work well in this side also then the increase in no of repeated guests will ultimately boost their revenue so Hotels can give alluring offers to non-repetitive customers during Off seasons to enhance revenue. So,right steps should be taken like taking feedbacks solving problems of customers within time limit and offering best offers to the customers.Answer Here.

# %% [markdown]
# #### Chart - 4 -**How does the price vary per night over the year?**

# %%
# Chart - 4 visualization code
# seperate resort and city hotel data for price comparision
data_resort = df[(df['hotel'] == 'Resort Hotel') & (df['is_canceled'] == 0)]
data_city = df[(df['hotel'] == 'City Hotel') & (df['is_canceled'] == 0)]

# %%
resort_hotel = data_resort.groupby(['arrival_date_month'])['adr'].mean().reset_index()
resort_hotel
# Out:
#    arrival_date_month         adr
# 0               April   76.841664
# 1              August  182.103524
# 2            December   64.072826
# 3            February   53.624311
# 4             January   48.599615
# 5                July  150.914540
# 6                June  109.026942
# 7               March   57.110018
# 8                 May   77.725129
# 9            November   48.956548
# 10            October   62.634853
# 11          September   98.855456

# %%
city_hotel=data_city.groupby(['arrival_date_month'])['adr'].mean().reset_index()
city_hotel
# Out:
#    arrival_date_month         adr
# 0               April  114.251636
# 1              August  122.825388
# 2            December   90.769559
# 3            February   88.210810
# 4             January   83.378062
# 5                July  120.069489
# 6                June  120.673753
# 7               March   91.306933
# 8                 May  124.825944
# 9            November   88.271089
# 10            October  105.517410
# 11          September  116.973279

# %%
final_hotel = resort_hotel.merge(city_hotel, on = 'arrival_date_month')
final_hotel.columns = ['month', 'price_for_resort', 'price_for_city_hotel']
final_hotel
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0       April         76.841664            114.251636
# 1      August        182.103524            122.825388
# 2    December         64.072826             90.769559
# 3    February         53.624311             88.210810
# 4     January         48.599615             83.378062
# 5        July        150.914540            120.069489
# 6        June        109.026942            120.673753
# 7       March         57.110018             91.306933
# 8         May         77.725129            124.825944
# 9    November         48.956548             88.271089
# 10    October         62.634853            105.517410
# 11  September         98.855456            116.973279

# %%
# !pip install sort-dataframeby-monthorweek

# !pip install sorted-months-weekdays
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sort-dataframeby-monthorweek: filename=sort_dataframeby_monthorweek-0.4-py3-none-any.whl size=3420 sha256=1c27bdf9b784b3fa22bb79b4e0cc2fdccf168d2c2d66a04f55c98a1a02d08215
#   Stored in directory: /root/.cache/pip/wheels/6b/fd/39/06eaac8d65d641f9f50856a48b57a5ec8351be2874beff01ec
# Successfully built sort-dataframeby-monthorweek
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sorted-months-weekdays: filename=sorted_months_weekdays-0.2-py3-none-any.whl size=3223 sha256=968ee5ee355f91a4bca2a0b2f1a0770b63d60c0cee90ff743dbf106d35dfa052
#   Stored in directory: /root/.cache/pip/wheels/bd/b4/f6/2c29a96668a9a13a568134857fd7b7a5186261f00f1d35661c
# Successfully built sorted-months-weekdays
# ...

# %%
import sort_dataframeby_monthorweek as sd

def sort_month(df, column_name):
    return sd.Sort_Dataframeby_Month(df, column_name)

# %%
final_prices = sort_month(final_hotel, 'month')
final_prices
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0     January         48.599615             83.378062
# 1    February         53.624311             88.210810
# 2       March         57.110018             91.306933
# 3       April         76.841664            114.251636
# 4         May         77.725129            124.825944
# 5        June        109.026942            120.673753
# 6        July        150.914540            120.069489
# 7      August        182.103524            122.825388
# 8   September         98.855456            116.973279
# 9     October         62.634853            105.517410
# 10   November         48.956548             88.271089
# 11   December         64.072826             90.769559

# %%
import plotly.express as px

# %%
plt.figure(figsize = (17, 8))

px.line(final_prices, x = 'month', y = ['price_for_resort','price_for_city_hotel'],
        title = 'Room price per night over the Months', template = 'plotly_dark')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I preffered line chart for comparision of hotel price per night per year because price vary over time for that line chart is best when we have to compare any data with time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Now we observe here that month column is not in order, and if we visualize we will get improper conclusions.
# So, first we have to provide right hierarchy to month column.
#
# This plot clearly shows that prices in the Resort Hotel are much higher during the summer and prices of city hotel varies less and is most expensive during Spring and Autumn .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, as we see through the graph that in summer season price of resort hotel is higher as compare to city hotel most peaple plan their holidays vacation so we can also increase the price of city hotel by providing some extra facility for bussiness persepective.

# %% [markdown]
# #### Chart - 5- **Which are the most busy Months?**

# %%
# Chart - 5 visualization code
resort_guests = data_resort['arrival_date_month'].value_counts().reset_index()
resort_guests.columns=['month','no of guests']
resort_guests
# Out:
#         month  no of guests
# 0      August          3153
# 1        July          3013
# 2         May          2246
# 3     October          2209
# 4       March          2191
# 5       April          2169
# 6    February          2053
# 7        June          1926
# 8   September          1875
# 9    November          1744
# 10   December          1716
# 11    January          1687

# %%
city_guests = data_city['arrival_date_month'].value_counts().reset_index()
city_guests.columns=['month','no of guests']
city_guests
# Out:
#         month  no of guests
# 0      August          4467
# 1        July          3834
# 2         May          3656
# 3        June          3477
# 4       March          3469
# 5       April          3325
# 6   September          3166
# 7     October          3070
# 8    February          2618
# 9    November          2177
# 10   December          2019
# 11    January          1961

# %%
final_guests = resort_guests.merge(city_guests,on='month')
final_guests.columns=['month','no of guests in resort','no of guest in city hotel']
final_guests= sort_month(final_guests,'month')
final_guests
# Out:
#         month  no of guests in resort  no of guest in city hotel
# 0     January                    1687                       1961
# 1    February                    2053                       2618
# 2       March                    2191                       3469
# 3       April                    2169                       3325
# 4         May                    2246                       3656
# 5        June                    1926                       3477
# 6        July                    3013                       3834
# 7      August                    3153                       4467
# 8   September                    1875                       3166
# 9     October                    2209                       3070
# 10   November                    1744                       2177
# 11   December                    1716                       2019

# %%
px.line(final_guests, x = 'month', y = ['no of guests in resort','no of guest in city hotel'],
        title='Total no of guests per Months', template = 'plotly_dark')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have picked the line chart here because it helps to show small shifts that may be getting hard to spot in other graphs. It helps show trends for different periods. They are easy to understand.So here we can easily track the change of number of bookings with respect to month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The City hotel has more guests during spring and autumn, when the prices are also highest, In July and August there are less visitors, although prices are lower.
#
# Guest numbers for the Resort hotel go down slighty from June to September, which is also when the prices are highest. Both hotels have the fewest guests during the winter.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From visualization it is clear that Yes, this provides a good insights that hotels should be well prepared for the month of July and August as maximum bookings takes place for this month.So better the preparation and good approach will definetely adds to the growth of Hotels.

# %% [markdown]
# #### Chart - 6- **Percentage distribution of required car parking spaces for customer**

# %%
# Chart - 6 visualization code
df['required_car_parking_spaces'].value_counts().plot.pie(autopct='%1.1f%%',shadow=False,figsize=(8,8),fontsize=15,labels=None)
labels=df['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces',fontsize=15)
plt.legend(bbox_to_anchor=(0.85,1), loc='upper left',labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have used pie chart here becuase it gives the output in a more understanding manner as here we can clearly see the different two colors reflecting the demand of car parking spaces by guests.So, it's a very useful chart to get proper insights as we can use other charts also but we have found it more relevant here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows that 21.6% guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,the insights gained from here definitely help the hotels to provide better services. It can be said that hotels need to work less on car parking spaces as only 1 car parking space was required by 8.3% of guests so it's better to have a limited car parking spaces and use that space for other important purposes rather than just letting it go unused.So,It's better to focus on other areas to increase quality of hotel rather than focusing mainly on car parking area only. The demand for car parking area is less. This might be due to the reason as many guests prefers to use public vechiles for travel.

# %% [markdown]
# #### Chart - 7-**Meal type Distribution(Univariate)**

# %%
# Chart - 7 visualizing using countplot for counting the types of meal:

plt.figure(figsize=(15,6))
sns.countplot(x=df['meal'])
plt.xlabel('Meal-Type',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title('Preffered Meal Type',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Preffered Meal Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have used this count plot because it Show the counts of observations in each categorical bin using bars. Bar plots look similar to count plots, but instead of the count of observations in each category, they show the mean of a quantitative variable among observations in each category.So, to get clear insights about the counts of different types of meal,We have used this count plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that we have found from the above graph is that the most preferred meal type by the guests is BB(Bed and Breakfast) while HB- (Half Board) and SC- (Self Catering) are equally preferred. Types of meal in hotels are as follows:-
#
# BB- (Bed and Breakfast) ,HB- (Half Board) ,FB- (Full Board) ,SC- (Self Catering)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# So,the insights here also have positive impact as hotels need to focus more on the BB meal type so that the majority of customers are satisfied while others type of meals should be given equal importance with proper management of food services so as to offer best services to customers.

# %% [markdown]
# #### Chart - 8- **Visualization code to check relationship between adr and distribution channel**

# %%
# Chart - 8 visualization code

# using groupby on distribution channel and hotel
distribution_channel_df=df.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# set plot size and plot barchart
plt.figure(figsize=(15,7))
sns.barplot(x='distribution_channel',y='adr',data=distribution_channel_df,hue='hotel')
plt.title('ADR across Distribution Channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution Channel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are used. Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages. To show the mean of adr with respect to the type of distribution channel, we have used Bar Chart So,this graph will help us to know about various distribution channel and their contribution to adr in order to increase the the income and revenue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart it is clear that 'Direct' and 'TA/TO' have almost equally contribution in adr in both type of hotels i.e. 'City Hotel' and 'Resot Hotel'.where GDS has highly contributed in adr in 'City Hotel' type.GDS needs to increase Resort Hotel bookings.These are corporate hotel booking companies which makes booking possible.The definitions of abbreviatons used in this graph are as followed:
# *  GDS- A GDS is a worldwide contact between travel bookers and suppliers.It communicates live product, price and availability data to travel agents and online booking engines and allows for automated trasactions.
# *  Direct: Means that booking directly made by respective hotel.
# *  TA/TO- Means that booking are made through travel agents or travel operators.
# *  Undifined- Bookings are undefined or customers made their bookinga on arrival.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From visualization we get that different distribution channels to work on spaces where they are lacking behind like GDS is lacking behind in the bookings of resort hotel.So we need to  taking proper steps to increase the overall revenue.

# %% [markdown]
# #### Chart - 9- **Pie chart for mostly used Distribuiton channel**

# %%
# Chart - 9 visualizing with the help of pie chart
# creating labels
labels=df['distribution_channel'].value_counts().index.tolist()

# creating new data frame of distribution channel
distribution_channel_df=df['distribution_channel'].value_counts().reset_index().rename(columns={'index':'distribution_channel','distribution_channel':'count'})

# Adding percentage column to the distribution_channel_df
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/df.shape[0],1)
# Creating list of percentage
sizes=distribution_channel_df['percentage'].values.tolist()

# plotting the pie chart
df['distribution_channel'].value_counts().plot.pie(figsize=(15,8), fontsize=10,labels=None)

# setting legendswith the percentage values
labels =[f'{l},{s}%' for l,s in zip(labels,sizes)]
plt.legend(bbox_to_anchor=(0.85,1),loc='upper left',labels=labels)
plt.title('Mostly used Distribution Channel for Hotel Bookings',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Mostly used Distribution Channel for Hotel Bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  We have used the pie chart to get clear understanding of mostly used booking distribution channel with occupancy percentage of each booking channel.A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, we have used Pie chart and which helped me to get the percentage comparision of the dependant variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart.We have found that "TA/TO' has been mostly (79.1%) used for booking hoetls. Direct constitues of 14.9%, Corporates constitutes of 5.8%,GDS constitutes of only 0.2% and rest unidentified are 0%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# So, from above graph, we have got the insights that 'TA/TO' is the leading one while Direct and Corporates have the potential to grow as they occupy much less space than the leading one.So,a good understanding and relation of Hotels with 'TA/TO' will definetely add up to the growth and revenue.

# %% [markdown]
# #### Chart - 10- **Year and Hotel wise confimed and cancelled bookings**

# %%
# Chart - 10 Hotel wise confirmation and cancellation of bookings using countplot

#set the size of figure
plt.figure(figsize=(12,8))
sns.countplot(x='hotel',data=df, hue='is_canceled')
plt.legend(['Confirmed','Canceled'])
plt.title('Hotel wise confirmation and cancellation of bookings',fontsize=15)
plt.xlabel('Hotel',fontsize=15)
plt.ylabel('Count of confirmation and Cancellations',fontsize=15)
# Out:
# Text(0, 0.5, 'Count of confirmation and Cancellations')

# %%
# removing cancelled bookings from the data and create a new df
confiremed_booking_df= df[df['is_canceled']==0]

# Year wise bookings of hotel using countplot
sns.set_style(style='darkgrid')
plt.figure(figsize=(12,6))
sns.countplot(x='arrival_date_year',data=confiremed_booking_df, hue='hotel',palette='tab10')
plt.legend(['Resort Hotel','City Hotel'])
plt.title('Year wise bookings of Hotels',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Number of Bokkings',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Bokkings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choosen the countplot for visualization because its comparision of number of bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we get from above graphs that the City hotel is having graeter number of bookings as compared to Resort hotel but cancellation percentage is high for City hotel.
#
# From above graphs, it can summerized that  in year 2016 both the hotel saw a massive increase in their bookings . In each year i.e. 2015,2016 and 2017 the city hotel having the highest number of bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,Overall the graphs show a positive outcome but the visualisation of cancellation graph ceates a situation of deep concern. So,Here as we can see, that more than 1/4th of overall booking got cancelled. So it's a matter of deep concern. Thus, we need to look over this problem. The solution to this problem is that We can check the reasons of cancellation of a booking & need to get this sorted out as soon as possible at the business level to stop the problems getting broader.

# %% [markdown]
# #### Chart - 11 - **Correlation Heatmap**

# %%
# Correlation Heatmap visualization code
plt.figure(figsize = (24, 12))

corr = df.corr()
sns.heatmap(corr, annot = True, linewidths = 1)
plt.title('Co-relation of the columns',fontsize=15)
plt.show()
# Out:
# <ipython-input-54-178fc47ff434>:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Chart-12- **Pair Plot**

# %%
# visualization using pair plot
sns.pairplot(df,hue='hotel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Co-relation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two
# variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [-1,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, we have used correlation heatmap

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the above chart are as follows:
#
# *  is canceled and total stay are negatively corelated. This means customers are unlikely to cancel their bookings if they don't get the same room as per reserved room. We have visualized it above.
#
# *  lead time and total stay is positively corelated. This means more the stay of cutsomer is, more will be the lead time.
#
# *  adults,childrens and babies are corelated to each other. This indicates more the people, more will be adr.
#
# *  is repeated guest and previous bookings not canceled have a strong corelation. This may be due to the reason that repeated guests are
#
# not more intersted to cancel their bookings.
#
# *  SO,these are some powerful insights found from the chart of corelation heatmap

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# visualization Using Pair Plot
sns.pairplot(df, hue="hotel")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.
#
# It's exactly same as the correlation map but here it shows the output in the graphical representation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We have found the relationship of "is_repeated_guest" with different types of columns.So.generally this chart reflects the relationship of a particular column with all other columns.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Business objective attained as follows:
#
# *  To attain high growth and more success, hotel business need to flourish and for that few things which we need to consider is high revenue generation, customers satisfaction and employee retention.
#
# *  We are able to achieve the same by showing the client which are the months which are high in revenue generation by using various charts and graphs distribution
#
# *  Enhancing the revenue adopted by bar chart distribution of which type room are most preffered and reserved and which are the months suitable for visitors
#
# *  we also have founded the varouses preferences in different categories like most liked meal type optimal stay length, facilities required by customers like cae parking spaces,etc.So,all these insights ultimately add to have a better planning for growth and higher revenue.
#
# *  So,preaparing well by using and understanding these useful outcomes, the client can be well prepared in advance so that minimum grievances would be faced by clients in long run and would help in further enhancement of their hospitality and service.
#
# *  Ask for feedback often from the guests visitng the hotels so that the quality can be upgraded to the next level to increase more guests.
#
# Periodically throw Offers to attract the old customers so as to increase the no of repeated guests.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *  City hotels are the most preferred hotel type by the guests. So, We can say that City hotels are the busiest hotel in comparision to the resort hotel.
#
# *  The average ADR of city hotels is higher as compared to the resort hotels. So,it can be said that these City hotels are generating more revenue than the resort hotels.
#
# *  The total stay of guests is directly proportional to the adr.So,higher the days of stay, the higher will be adr and revenue as well.
#
# *  The percentage of repeated guests is very low. Only 3.9 % people had revisited the hotels. Rest 96.1% were new guests. So, retention rate is much low.
#
# *  The percentage of required car parking spaces is very low. This means less car parking spaces don't affect the business much.Most of the customers (91.6%) do not require car parking spaces.
#
# *  Among different types of meals,BB( Bed & Breakfast) is the most preferred type of meal by the guests. So, Guests loved to opt for this meal type.
#
# *  'Direct' and 'TA/TO' have almost equally contribution in adr in both type of hotels i.e. 'City Hotel' and 'Resort Hotel. While, GDS has highly contributed in adr in 'City Hotel' type.
#
# *  Optimal stay length in both the hotel types(City and Resort Hotel) is less than 7 days. Usually people stay for a week. So,after 1 week, the optimal stay length decined drastically.
#
# *  Most number of bookings have taken place in the month of July and August July and August are the favourite months of guests to visit different places.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
